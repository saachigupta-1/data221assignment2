# %%
import requests
from bs4 import BeautifulSoup

url = "https://en.wikipedia.org/wiki/Data_science"

headers = {
    "User-Agent": "Mozilla/5.0"
}


response = requests.get(url, headers=headers)


soup = BeautifulSoup(response.text, "html.parser")


if soup.title is not None:
    print("Title:", soup.title.text)
else:
    print("Title not found")

content_div = soup.find("div", id="mw-content-text")

if content_div is not None:
    for p in content_div.find_all("p"):
        text = p.get_text(strip=True)
        if len(text) >= 50:
            print("\nFirst paragraph:")
            print(text)
            break
else:
    print("Main content not found")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 11
#       5 http_response = requests.get(wikipedia_page_url)
#       7 parsed_html_page = BeautifulSoup(
#       8     http_response.text, "html.parser"
#       9 )
# ---> 11 page_title_text = parsed_html_page.title.text
#      12 print("Title:", page_title_text)
#      14 main_content_div = parsed_html_page.find(
#      15     "div", id="mw-content-text"
#      16 )
#
# AttributeError: 'NoneType' object has no attribute 'text'
